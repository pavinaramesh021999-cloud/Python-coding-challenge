# %% [markdown]
# <a href="https://colab.research.google.com/github/pavinaramesh021999-cloud/Python-coding-challenge/blob/main/Day40_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 40 – List Methods and Slicing
#
# Project Title: Contact Directory
#
# Scenario:
#
# You have been assigned to build a contact management system where employees can store and retrieve contact details efficiently. Tasks: Create a 2D list where each row holds a contact’s name, phone number, and email address. Allow the user to add a new contact. Display all contacts sorted alphabetically by name. Allow the user to search for contacts by name. The search should support partial matches. After sorting, display only the first 3 contacts in the list

# %%
# 1. Create a 2D list of contacts (name, phone, email)
contacts = [
    ["Nandhini", "9600711126", "nandhu@gmail.com"],
    ["Malathi",   "9164572150", "Malathi@gmail.com"],
    ["Pavi", "9994211126", "pavi@gmail.com"]
]


# 2. Allow the user to add a new contact
print("Add a new contact:")
name = input("Enter name: ")
phone = input("Enter phone number: ")
email = input("Enter email: ")
contacts.append([name, phone, email])
print("\nContact added successfully!\n")


# 3. Display all contacts sorted alphabetically by name
contacts.sort(key=lambda x: x[0])   # sort by the first element (name)

print("All Contacts (Sorted Alphabetically):")
for c in contacts:
    print(f"Name: {c[0]}, Phone: {c[1]}, Email: {c[2]}")

# 4. Allow user to search for contacts (partial matches allowed)
search = input("\nEnter name to search (partial match supported): ").lower()

print("\nSearch Results:")
found = False
for c in contacts:
    if search in c[0].lower():  # partial match check
        print(f"Name: {c[0]}, Phone: {c[1]}, Email: {c[2]}")
        found = True

if not found:
    print("No matching contacts found.")

# 5. Display only the first 3 contacts after sorting
print("\nFirst 3 contacts after sorting:")
for c in contacts[:3]:   # slicing to get first 3
    print(f"Name: {c[0]}, Phone: {c[1]}, Email: {c[2]}")
# Out:
# Add a new contact:
# Enter name: pavi
# Enter phone number: 8088943867
# Enter email: pavi@email.com
#
# Contact added successfully!
#
# All Contacts (Sorted Alphabetically):
# Name: Malathi, Phone: 9164572150, Email: Malathi@gmail.com
# Name: Nandhini, Phone: 9600711126, Email: nandhu@gmail.com
# Name: Pavi, Phone: 9994211126, Email: pavi@gmail.com
# Name: pavi, Phone: 8088943867, Email: pavi@email.com
#
# Enter name to search (partial match supported): Nanthini
#
# Search Results:
# No matching contacts found.
#
# First 3 contacts after sorting:
# Name: Malathi, Phone: 9164572150, Email: Malathi@gmail.com
# Name: Nandhini, Phone: 9600711126, Email: nandhu@gmail.com
# Name: Pavi, Phone: 9994211126, Email: pavi@gmail.com
