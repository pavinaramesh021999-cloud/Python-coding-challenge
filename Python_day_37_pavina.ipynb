# %% [markdown]
# <a href="https://colab.research.google.com/github/pavinaramesh021999-cloud/Python-coding-challenge/blob/main/Python_day_37_pavina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Project Title: Student Profile Creator ---
student_name = "Pavina"
Enroll_No = " 1253"
student_age = 24
favourite_subjects = ["English", "Science", "Maths"]

print(" ----  Student Profile  ---- ")
print(f"Name: {student_name}")
print(f"Enroll No : { Enroll_No}")
print(f"Age: {student_age}")
print("Favourite Subjects:")
for subject in favourite_subjects:
    print(f" - {subject}")

# student chooses a new subject
new_subject = "Computer Science"
favourite_subjects.append(new_subject)

# Updated subject list
print("\n---- Updated Subjects ----")
for subject in favourite_subjects:
    print(f" - {subject}")
# Out:
#  ----  Student Profile  ----
# Name: Pavina
# Enroll No :  1253
# Age: 24
# Favourite Subjects:
#  - English
#  - Science
#  - Maths
#
# ---- Updated Subjects ----
#  - English
#  - Science
#  - Maths
#  - Computer Science
